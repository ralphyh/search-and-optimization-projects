# %%
import ast
import json
import scipy.stats as stat
# %run data_plot.ipynb
# %run metrics.ipynb
# %run discrete_genetic_algorithm.ipynb
# %run ant_colony_optimization.ipynb
# %run dijkstras_algorithm.ipynb
# %run simulated_annealing.ipynb

# %%
def parse_map_data(results):
    """
    parse_map_data(results)
    converts routes data to geographic routes that can be represented on a map.
    this is done by checking the sequence of x y coordinates against their corresponding
    geographic coordinates defined in the plotting module.
    results: the algorithm search results that contains the best solution to the destination
    and all other possible routes.
    returns: the coordinates used to create the map representation
    """
    # init dictionary with the structure expected for map visualization
    coordinates = {'best_route': {'sensor_id': [],
                              'coordinates': []}, 
               'possible_routes': []
              }
    # convert the string containing the list of the best path to type list
    possible_paths = [ast.literal_eval(paths) for paths in results['possible_paths'].keys()]
    # get the geographic coordinates for all nodes in possible paths
    for path in possible_paths:
        route_coords = []
        possible_path_dest_idx = len(path) - 1
        for idx, sensor in enumerate(path):
            if idx != 0 and idx != possible_path_dest_idx:
                # duplicate coordinates for all nodes but for the first and last
                route_coords.append(geographic_coords[str(sensor)])
                route_coords.append(geographic_coords[str(sensor)])
            else:
                route_coords.append(geographic_coords[str(sensor)])
        coordinates['possible_routes'].append(route_coords)
    # add best path last so that an visual it appears on top
    best_path = ast.literal_eval(list(results['best_path'].keys())[0])
    best_path_dest_idx = len(best_path) - 1
    for idx, sensor in enumerate(best_path):
        # include sensor IDs for the best path except for the destination (won't need pin marker)
        if idx != best_path_dest_idx:
            coordinates['best_route']['sensor_id'].append(sensor)
        if idx != 0 and idx != best_path_dest_idx:
            # duplicate coordinates for all nodes but for the first and last
            coordinates['best_route']['coordinates'].append(geographic_coords[str(sensor)])
            coordinates['best_route']['coordinates'].append(geographic_coords[str(sensor)])
        else:
            coordinates['best_route']['coordinates'].append(geographic_coords[str(sensor)])

    return coordinates

# %%
def save_solution(solution, method):
    """
    save_solution(solution, method)
    saves the best solution found by each algorithm in a solutions json file.
    the solutions file has a format like...
    {"source node": "Node-5", 
    "routing path": "(Node-2, 1 Mbps), (Node-1, 4Mbps), (BS-2, 2 Mbps)",
    "end-to-end transmission rate": "1 Mbps"}
    solution: the best solution to a base station from a sensor
    method: the method that was used to get that best solution.
    returns: nothing
    """
    # fetch existing solutions
    existing_solutions = load_solutions()
    '''
    if solution for a sensor using the method specified exists, 
    update the dict with a new solution, otherwise create the solution
    '''
    if method in existing_solutions.keys():
        existing_solutions[method][solution[0]['source node']] = solution[0]
    else:
        existing_solutions[method] = {}
        existing_solutions[method][solution[0]['source node']] = solution[0]
    # write the updated solutions to the solutions file
    json.dump(existing_solutions, open( f"solutions.json", 'w' ) )

    return

# %%
def load_solutions():
    """
    load_solutions()
    it loads solutions that already exist since new solutions are appended to the json
    object before being added written on the file.
    returns: the json object read from the file
    """
    # fetch existing best solutions from the solutions file
    with open('solutions.json', 'r') as file:
        try:
            solutions = json.load(file)
        except Exception as e:
            # if the solutions file is empty, initialize and empty dict to be used
            solutions = {}

    return solutions

# %%
def get_missing_solutions():
    """
    get_missing_solutions()
    for each algorithm, it gets the nodes that dont have any documented
    solutions to any of the based stations. This is based on the records
    found in the solutions json file.
    returns: a dictionary containing the missing solution for each algorithm
    """
    missing_solutions = {}
    sensors = list(x_y_data.keys())[:-2]
    solutions = load_solutions()

    for algorithm in solutions.keys():
        for sensor in sensors:
            if solutions[algorithm].get(f"Node-{sensor}") == None:
                if algorithm in missing_solutions.keys():
                    missing_solutions[algorithm].append(sensor)
                else:
                    missing_solutions[algorithm] = []
                    missing_solutions[algorithm].append(sensor)

    return missing_solutions

# %%
#get_missing_solutions()
# Out:
# {'discrete genetic algorithm': [1,
#   2,
#   4,
#   8,
#   11,
#   12,
#   13,
#   17,
#   20,
#   25,
#   27,
#   28,
#   36,
#   37,
#   38,
#   40,
#   42,
#   47,
#   48,
#   55,
#   59,
#   66,
#   71,
#   75,
#   76,
#   82,
#   83,
#   86,
#   88,
#   91,
#   92,
#   93,
#   94,
#   96,
#   98,
#   100,
#   101,
#   106,
#   109,
#   110,
#   114,
#   115,
#   120,
#   127,
#   128,
#   132,
#   133,
#   134,
#   135,
#   136,
#   137,
#   139,
#   146,
#   147,
#   150]}

# %%
def find_optimal_route(origin, method, **kwargs):
    """
    find_optimal_route(origin, method, **kwargs)
    the main function of this assessment. It searches for best route 
    from a node to either of the 2 base stations. The search is done using
    the algorithm specified as one of the arguments. Supported algorithms 
    include: 'discrete genetic algorithm', 'ant colony optimization', 
    'dijkstras algorithm' and 'simulated annealing'. Each of the algorithms,
    return a best solutions dictionary that is stored in the solutions file,
    and the results dictionary which is used for visualization on a map
    origin: the node whose best path to a base station you are seeking
    method: the algorithm you want to use to perform the search
    **kwargs: any additional arguments you want to pass in for
    optimization of the various algoithms
    Expected **kwargs and their defults:
    discrete genetic algorithm: pop_length=100000, generations=10, mutation_rate=0.1, crossover_type='single-point', selection_limit=20
    ant colony optimization: Q=1, alpha = 0.6, evaporate=0.45, ants_count=20, max_iterations=10
    dijkstras algorithm: None
    simulated annealing: init_temp=100, final_temp=0.1, cooling_rate=0.95, improvement_checker_count=50
    More details on the **kwargs provided in the algorithms' respective modules
    returns: nothing
    """
    # run the algorithm passed in as a parameter and fetch the visualization results together with the solutions file data
    if method == "discrete genetic algorithm":
        results, solutions = discrete_genetic_algorithm(origin, **kwargs)
    elif method == "dijkstras algorithm":
        results, solutions = dijkstra_algorithm(origin)
    elif method == "ant colony optimization":
        results, solutions = ant_colony_optimization(origin, **kwargs)
    elif method == "simulated annealing":
        results, solutions = simulated_annealing(origin, **kwargs)
    else:
        return "unknown algorithm"
    # save the best path in the solutions file
    save_solution(solutions, method)
    # parse the plotting results and call the map visualization function
    #coordinates = parse_map_data(results)
    #plot_route(coordinates)

    return

# %%
#find_optimal_route(43, 'discrete genetic algorithm', pop_length=100000)
#find_optimal_route(1, 'ant colony optimization')
#find_optimal_route(101, 'simulated annealing')

# %%
def run_all():
    """
    run_all()
    executes the find_optimal_route() function for all sensors using all algorithms
    for purposes of storing the best solutions for each in the solutions file.
    returns: nothing
    """
    # algorithms to be executed
    methods = ['discrete genetic algorithm', 'ant colony optimization', 'dijkstras algorithm', 'simulated annealing']
    # all sensors except the 2 base stations
    sensors = list(x_y_data.keys())[:-2]
    # for each method, find the best path for each sensor
    for method in methods:
        for sensor in sensors:
            # ignore situations where no best paths will be found. This is typical with DGA and it will kill the function
            try:
                print(f"Sensor {sensor}")
                find_optimal_route(sensor, method)
            except:
                pass        

    return

# %%
#run_all()

# %%
def get_algorithm_time_metrics():
    """
    get_algorithm_time_metrics()
    this function compares the performance of the various algorithms 
    in terms of execution time and plots them on a bar graph. This is done
    by setting a timer at the beginning of execution of an algorithm and stopping
    it at the end of the execution. The duration is stored in a dictionary against
    the algorithm name as a key in the stop_execution() function. These functions
    are found in the found in the metrics module. The durations are plotted on a
    bar graph for visualization purposes.
    returns: nothing
    """
    # choose any random node to start from with the exception of the base stations
    dest_nodes = [x_y_base_station_1[0], x_y_base_station_2[0]]
    start_node = choice(np.array([i for i in x_y_data.keys() if i not in dest_nodes]), 1, replace=False)[0]
    # list of algorithms whose time performance will be compared
    methods = ['discrete genetic algorithm', 'ant colony optimization', 'dijkstras algorithm', 'simulated annealing']
    for method in methods:
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print(f"executing {method}...")
        # start execution timer
        start_execution()
        # run the algorithm
        find_optimal_route(start_node, method)
        # stop the timer and record the results
        stop_execution(method)
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    # plot the recorded results
    plot_algorithm_execution_time()

    return

# %%
get_algorithm_time_metrics()
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing discrete genetic algorithm...
# **********************************Generation 1**********************************
# ********************************************Performance**********************************
# *****************************************************************************************
# No Solution Found to base station ID 151
# **********************************Generation 1**********************************
# ********************************************Performance**********************************
# Chromosome: [108  44 152]-----actual route: 108->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [108  70 152]-----actual route: 108->70->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108   3 152]-----actual route: 108->3->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 104 152]-----actual route: 108->104->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108  99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 111 152]-----actual route: 108->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108 142 152]-----actual route: 108->142->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 142 111 152]-----actual route: 108->142->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108 126 152]-----actual route: 108->126->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108  68 125 152]-----actual route: 108->68->125->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108  56 152]-----actual route: 108->56->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108  69 152]-----actual route: 108->69->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108  69 119  51 152]-----actual route: 108->69->119->51->152->----Score (end-to-end path cost): 2.25
# Chromosome: [108 142 123 152]-----actual route: 108->142->123->152->----Score (end-to-end path cost): 4.667
# Chromosome: [108  23 152]-----actual route: 108->23->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108  39 126 152]-----actual route: 108->39->126->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108 104 111 152]-----actual route: 108->104->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108  60 152]-----actual route: 108->60->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108  26 125 152]-----actual route: 108->26->125->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108 142 104 152]-----actual route: 108->142->104->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108  51 152]-----actual route: 108->51->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108  70 104 111 152]-----actual route: 108->70->104->111->152->----Score (end-to-end path cost): 3.25
# Chromosome: [108 144 123 152]-----actual route: 108->144->123->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108 125 152]-----actual route: 108->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108 111 126 152]-----actual route: 108->111->126->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108 104  69 152]-----actual route: 108->104->69->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108  63 111 152]-----actual route: 108->63->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108  99  44 152]-----actual route: 108->99->44->152->----Score (end-to-end path cost): 4.667
# Chromosome: [108  33 104 152]-----actual route: 108->33->104->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 2**********************************
# ********************************************Performance**********************************
# Chromosome: [108 44 152]-----actual route: 108->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [108 70 152]-----actual route: 108->70->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 3 152]-----actual route: 108->3->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 104 152]-----actual route: 108->104->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 111 152]-----actual route: 108->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108, 142, 152]-----actual route: 108->142->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 142 111 152]-----actual route: 108->142->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108, 56, 152]-----actual route: 108->56->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 142 123 152]-----actual route: 108->142->123->152->----Score (end-to-end path cost): 4.667
# Chromosome: [108  23 152]-----actual route: 108->23->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108, 104, 111, 152]-----actual route: 108->104->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108, 51, 152]-----actual route: 108->51->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108, 144, 123, 152]-----actual route: 108->144->123->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108, 125, 152]-----actual route: 108->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108  63 111 152]-----actual route: 108->63->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108  99  44 152]-----actual route: 108->99->44->152->----Score (end-to-end path cost): 4.667
# Chromosome: [108  33 104 152]-----actual route: 108->33->104->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108, 111, 142, 152]-----actual route: 108->111->142->152->----Score (end-to-end path cost): 2.667
# Chromosome: [108, 23, 123, 152]-----actual route: 108->23->123->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108 63 44 152]-----actual route: 108->63->44->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108 99 111 152]-----actual route: 108->99->111->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 3**********************************
# ********************************************Performance**********************************
# Chromosome: [108 44 152]-----actual route: 108->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [108 70 152]-----actual route: 108->70->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 142 111 152]-----actual route: 108->142->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108 142 123 152]-----actual route: 108->142->123->152->----Score (end-to-end path cost): 4.667
# Chromosome: [108, 23, 152]-----actual route: 108->23->152->----Score (end-to-end path cost): 3.5
# Chromosome: [108, 104, 111, 152]-----actual route: 108->104->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108, 125, 152]-----actual route: 108->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [108, 33, 104, 152]-----actual route: 108->33->104->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108 63 44 152]-----actual route: 108->63->44->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 4**********************************
# ********************************************Performance**********************************
# Chromosome: [108 44 152]-----actual route: 108->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108, 123, 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108, 104, 111, 152]-----actual route: 108->104->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108 63 44 152]-----actual route: 108->63->44->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108, 111, 104, 152]-----actual route: 108->111->104->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 5**********************************
# ********************************************Performance**********************************
# Chromosome: [108 44 152]-----actual route: 108->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108, 123, 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108, 104, 111, 152]-----actual route: 108->104->111->152->----Score (end-to-end path cost): 3.667
# Chromosome: [108, 111, 104, 152]-----actual route: 108->111->104->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 6**********************************
# ********************************************Performance**********************************
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# *****************************************************************************************
# **********************************Generation 7**********************************
# ********************************************Performance**********************************
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# *****************************************************************************************
# **********************************Generation 8**********************************
# ********************************************Performance**********************************
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# *****************************************************************************************
# **********************************Generation 9**********************************
# ********************************************Performance**********************************
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# *****************************************************************************************
# **********************************Generation 10**********************************
# ********************************************Performance**********************************
# Chromosome: [108 99 152]-----actual route: 108->99->152->----Score (end-to-end path cost): 6.5
# Chromosome: [108 123 152]-----actual route: 108->123->152->----Score (end-to-end path cost): 6.5
# *****************************************************************************************
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing ant colony optimization...
# ant 1: ({'start_node': 135, 'destination_node': 151, 'paths': [{'path': [135, 129, 28, 99, 20, 122, 105, 82, 34, 22, 75, 137, 62, 151], 'end-to-end_transmission': 0, 'latency': 390, 'cost': 0}, {'path': [135, 53, 29, 60, 12, 7, 142, 18, 100, 113, 36, 151], 'end-to-end_transmission': 0, 'latency': 330, 'cost': 0}, {'path': [135, 47, 117, 27, 61, 67, 120, 43, 151], 'end-to-end_transmission': 0, 'latency': 240, 'cost': 0}, {'path': [135, 41, 118, 74, 37, 94, 145, 84, 73, 81, 59, 86, 144, 50, 125, 152, 116, 151], 'end-to-end_transmission': 0, 'latency': 510, 'cost': 0}, {'path': [135, 136, 112, 8, 4, 5, 118, 93, 100, 126, 86, 46, 53, 151], 'end-to-end_transmission': 0, 'latency': 390, 'cost': 0}, {'path': [135, 41, 43, 138, 86, 59, 101, 110, 29, 151], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [135, 85, 64, 113, 130, 110, 68, 141, 5, 121, 26, 21, 138, 124, 28, 61, 105, 14, 53, 151], 'end-to-end_transmission': 0, 'latency': 570, 'cost': 0}, {'path': [135, 94, 134, 36, 150, 6, 77, 151], 'end-to-end_transmission': 0, 'latency': 210, 'cost': 0}, {'path': [135, 87, 92, 41, 62, 72, 57, 53, 97, 151], 'end-to-end_transmission': 1, 'latency': 270, 'cost': 4.556}, {'path': [135, 10, 115, 129, 49, 72, 77, 151], 'end-to-end_transmission': 2, 'latency': 210, 'cost': 2.714}]})
# --------------------------------------------------------
# --------------------------------------------------------
# ant 4: ({'start_node': 100, 'destination_node': 152, 'paths': [{'path': [100, 93, 75, 119, 42, 44, 13, 129, 141, 31, 116, 139, 34, 114, 27, 61, 2, 76, 152], 'end-to-end_transmission': 0, 'latency': 540, 'cost': 0}, {'path': [100, 9, 52, 69, 137, 64, 36, 61, 12, 71, 4, 46, 152], 'end-to-end_transmission': 0, 'latency': 360, 'cost': 0}, {'path': [100, 79, 7, 15, 59, 101, 130, 152], 'end-to-end_transmission': 0, 'latency': 210, 'cost': 0}, {'path': [100, 46, 108, 104, 3, 132, 25, 124, 123, 56, 152], 'end-to-end_transmission': 0, 'latency': 300, 'cost': 0}, {'path': [100, 77, 92, 41, 19, 29, 145, 13, 48, 17, 53, 107, 75, 108, 125, 152], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [100, 94, 127, 40, 8, 149, 76, 20, 93, 84, 145, 62, 72, 151, 77, 152], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [100, 8, 114, 16, 29, 110, 7, 98, 12, 140, 129, 28, 61, 62, 72, 112, 14, 84, 73, 152], 'end-to-end_transmission': 0, 'latency': 570, 'cost': 0}, {'path': [100, 1, 110, 29, 16, 26, 51, 15, 145, 61, 28, 129, 140, 144, 121, 25, 113, 68, 69, 108, 125, 152], 'end-to-end_transmission': 0, 'latency': 630, 'cost': 0}, {'path': [100, 94, 135, 6, 150, 58, 148, 101, 79, 7, 98, 143, 130, 110, 68, 141, 33, 142, 125, 108, 99, 152], 'end-to-end_transmission': 0, 'latency': 630, 'cost': 0}, {'path': [100, 93, 96, 59, 79, 7, 35, 135, 106, 6, 10, 139, 107, 80, 70, 44, 125, 142, 99, 152], 'end-to-end_transmission': 1, 'latency': 570, 'cost': 5.263}]})
# --------------------------------------------------------
# ant 5: ({'start_node': 145, 'destination_node': 151, 'paths': [{'path': [145, 152, 37, 46, 107, 61, 85, 90, 5, 116, 64, 151], 'end-to-end_transmission': 0, 'latency': 330, 'cost': 0}, {'path': [145, 115, 132, 130, 108, 27, 117, 152, 146, 15, 93, 118, 82, 151], 'end-to-end_transmission': 0, 'latency': 390, 'cost': 0}, {'path': [145, 62, 65, 63, 57, 139, 76, 87, 26, 131, 22, 81, 5, 27, 150, 53, 116, 114, 85, 91, 130, 94, 21, 151], 'end-to-end_transmission': 0, 'latency': 690, 'cost': 0}, {'path': [145, 15, 14, 135, 34, 10, 139, 137, 37, 9, 130, 65, 134, 31, 24, 151], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [145, 27, 14, 74, 24, 38, 151], 'end-to-end_transmission': 0, 'latency': 180, 'cost': 0}, {'path':
_transmission': 1, 'latency': 660, 'cost': 2.227}, {'path': [15, 145, 90, 84, 41, 43, 72, 97, 151, 53, 14, 112, 5, 121, 144, 108, 125, 152], 'end-to-end_transmission': 0, 'latency': 510, 'cost': 0}, {'path': [15, 14, 78, 12, 18, 46, 120, 49, 62, 43, 45, 95, 7, 106, 54, 110, 69, 108, 99, 152], 'end-to-end_transmission': 0, 'latency': 570, 'cost': 0}]})
# --------------------------------------------------------
# ant 11: ({'start_node': 7, 'destination_node': 151, 'paths': [{'path': [7, 141, 33, 117, 61, 78, 37, 47, 124, 51, 139, 39, 62, 137, 135, 34, 151], 'end-to-end_transmission': 0, 'latency': 480, 'cost': 0}, {'path': [7, 110, 62, 109, 55, 105, 82, 134, 29, 42, 20, 64, 126, 103, 151], 'end-to-end_transmission': 0, 'latency': 420, 'cost': 0}, {'path': [7, 119, 62, 117, 142, 5, 150, 145, 26, 151], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [7, 84, 71, 70, 139, 20, 134, 123, 29, 86, 38, 114, 85, 32, 137, 151], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [7, 106, 57, 72, 151], 'end-to-end_transmission': 0, 'latency': 120, 'cost': 0}, {'path': [7, 121, 98, 83, 143, 2, 73, 53, 151], 'end-to-end_transmission': 0, 'latency': 240, 'cost': 0}, {'path': [7, 16, 79, 139, 35, 101, 136, 87, 145, 14, 112, 61, 118, 43, 28, 125, 108, 56, 94, 100, 8, 146, 20, 93, 40, 77, 151], 'end-to-end_transmission': 0, 'latency': 780, 'cost': 0}, {'path': [7, 45, 129, 28, 72, 57, 53, 151], 'end-to-end_transmission': 1, 'latency': 210, 'cost': 4.714}, {'path': [7, 22, 142, 44, 80, 119, 113, 64, 89, 129, 85, 6, 150, 136, 100, 55, 128, 15, 14, 53, 151], 'end-to-end_transmission': 0, 'latency': 600, 'cost': 0}, {'path': [7, 95, 110, 33, 141, 130, 34, 56, 99, 108, 3, 24, 148, 79, 98, 138, 112, 84, 97, 77, 151], 'end-to-end_transmission': 1, 'latency': 600, 'cost': 2.25}]})
# --------------------------------------------------------
# ant 12: ({'start_node': 7, 'destination_node': 152, 'paths': [{'path': [7, 19, 140, 152], 'end-to-end_transmission': 0, 'latency': 90, 'cost': 0}, {'path': [7, 73, 79, 91, 30, 98, 14, 60, 2, 152], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [7, 111, 48, 133, 21, 114, 54, 116, 86, 1, 74, 40, 106, 55, 12, 140, 151, 89, 16, 24, 87, 4, 152], 'end-to-end_transmission': 0, 'latency': 660, 'cost': 0}, {'path': [7, 79, 138, 131, 20, 101, 113, 151, 94, 115, 65, 69, 57, 142, 104, 108, 125, 147, 145, 89, 16, 152], 'end-to-end_transmission': 0, 'latency': 630, 'cost': 0}, {'path': [7, 33, 117, 39, 130, 108, 125, 80, 50, 70, 74, 137, 76, 136, 152], 'end-to-end_transmission': 0, 'latency': 420, 'cost': 0}, {'path': [7, 110, 3, 104, 50, 141, 126, 60, 111, 70, 51, 144, 121, 18, 149, 15, 46, 140, 129, 45, 103, 152], 'end-to-end_transmission': 0, 'latency': 630, 'cost': 0}, {'path': [7, 110, 54, 68, 113, 16, 26, 51, 5, 121, 144, 86, 100, 1, 126, 42, 152], 'end-to-end_transmission': 0, 'latency': 480, 'cost': 0}, {'path': [7, 33, 141, 126, 60, 111, 125, 152], 'end-to-end_transmission': 2, 'latency': 210, 'cost': 2.714}, {'path': [7, 98, 12, 140, 45, 129, 138, 124, 25, 113, 64, 108, 125, 111, 70, 127, 93, 20, 146, 44, 152], 'end-to-end_transmission': 0, 'latency': 600, 'cost': 0}, {'path': [7, 130, 68, 141, 33, 144, 56, 44, 152], 'end-to-end_transmission': 3, 'latency': 240, 'cost': 3.625}]})
# --------------------------------------------------------
# ant 13: ({'start_node': 81, 'destination_node': 151, 'paths': [{'path': [81, 66, 28, 92, 74, 123, 3, 151], 'end-to-end_transmission': 0, 'latency': 210, 'cost': 0}, {'path': [81, 63, 20, 136, 51, 87, 114, 8, 43, 120, 9, 36, 132, 141, 149, 125, 108, 131, 151], 'end-to-end_transmission': 0, 'latency': 540, 'cost': 0}, {'path': [81, 124, 83, 151], 'end-to-end_transmission': 0, 'latency': 90, 'cost': 0}, {'path': [81, 27, 107, 7, 55, 31, 33, 14, 13, 15, 73, 69, 68, 40, 50, 122, 151], 'end-to-end_transmission': 0, 'latency': 480, 'cost': 0}, {'path': [81, 43, 41, 92, 62, 72, 151], 'end-to-end_transmission': 3, 'latency': 180, 'cost': 3.833}, {'path': [81, 15, 14, 53, 151], 'end-to-end_transmission': 2, 'latency': 120, 'cost': 5.25}, {'path': [81, 27, 66, 38, 59, 78, 90, 62, 72, 57, 53, 151], 'end-to-end_transmission': 0, 'latency': 330, 'cost': 0}, {'path': [81, 49, 28, 84, 145, 90, 77, 97, 72, 53, 151], 'end-to-end_transmission': 3, 'latency': 300, 'cost': 4.5}, {'path': [81, 124, 105, 73, 62, 72, 151], 'end-to-end_transmission': 2, 'latency': 180, 'cost': 3.833}, {'path': [81, 28, 43, 41, 62, 72, 53, 151], 'end-to-end_transmission': 3, 'latency': 210, 'cost': 4.714}]})
# --------------------------------------------------------
# ant 14: ({'start_node': 81, 'destination_node': 152, 'paths': [{'path': [81, 1, 118, 106, 152], 'end-to-end_transmission': 0, 'latency': 120, 'cost': 0}, {'path': [81, 46, 29, 118, 12, 60, 104, 98, 110, 14, 23, 37, 84, 73, 53, 8, 16, 120, 41, 92, 152], 'end-to-end_transmission': 0, 'latency': 600, 'cost': 0}, {'path': [81, 27, 118, 119, 95, 11, 152], 'end-to-end_transmission': 0, 'latency': 180, 'cost': 0}, {'path': [81, 124, 138, 113, 128, 58, 89, 16, 69, 108, 125, 152], 'end-to-end_transmission': 0, 'latency': 330, 'cost': 0}, {'path': [81, 37, 49, 62, 145, 61, 41, 35, 130, 111, 125, 152], 'end-to-end_transmission': 1, 'latency': 330, 'cost': 2.455}, {'path': [81, 27, 73, 70, 104, 108, 125, 152], 'end-to-end_transmission': 0, 'latency': 210, 'cost': 0}, {'path': [81, 15, 97, 151, 117, 39, 123, 3, 24, 87, 88, 127, 94, 100, 93, 21, 79, 91, 99, 152], 'end-to-end_transmission': 0, 'latency': 570, 'cost': 0}, {'path': [81, 43, 41, 35, 150, 133, 76, 8, 100, 17, 40, 93, 119, 80, 142, 99, 152], 'end-to-end_transmission': 0, 'latency': 480, 'cost': 0}, {'path': [81, 49, 120, 41, 43, 138, 19, 148, 58, 64, 116, 139, 7, 106, 130, 65, 69, 108, 99, 152], 'end-to-end_transmission': 1, 'latency': 570, 'cost': 5.263}, {'path': [81, 43, 138, 64, 113, 119, 80, 142, 125, 152], 'end-to-end_transmission': 2, 'latency': 270, 'cost': 2.556}]})
# --------------------------------------------------------
# ant 15: ({'start_node': 57, 'destination_node': 151, 'paths': [{'path': [57, 53, 5, 140, 144, 27, 37, 58, 74, 2, 95, 75, 128, 70, 18, 49, 79, 151], 'end-to-end_transmission': 0, 'latency': 510, 'cost': 0}, {'path': [57, 94, 35, 104, 23, 124, 103, 11, 138, 38, 118, 33, 49, 151], 'end-to-end_transmission': 0, 'latency': 390, 'cost': 0}, {'path': [57, 72, 147, 45, 25, 142, 5, 151], 'end-to-end_transmission': 0, 'latency': 210, 'cost': 0}, {'path': [57, 72, 62, 61, 105, 120, 82, 78, 25, 16, 129, 102, 123, 46, 140, 47, 109, 147, 104, 3, 55, 34, 151], 'end-to-end_transmission': 0, 'latency': 660, 'cost': 0}, {'path': [57, 97, 116, 111, 41, 118, 74, 37, 107, 34, 88, 102, 39, 123, 33, 151], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [57, 97, 151], 'end-to-end_transmission': 4, 'latency': 60, 'cost': 6.5}, {'path': [57, 53, 151], 'end-to-end_transmission': 4, 'latency': 60, 'cost': 6.5}, {'path': [57, 53, 151], 'end-to-end_transmission': 4, 'latency': 60, 'cost': 6.5}, {'path': [57, 72, 112, 105, 143, 89, 46, 138, 140, 19, 135, 150, 20, 93, 21, 54, 110, 69, 152, 45, 43, 81, 15, 97, 151], 'end-to-end_transmission': 0, 'latency': 720, 'cost': 0}, {'path': [57, 72, 112, 138, 124, 145, 90, 77, 53, 14, 15, 97, 151], 'end-to-end_transmission': 2, 'latency': 360, 'cost': 4.417}]})
# --------------------------------------------------------
# ant 16: ({'start_node': 57, 'destination_node': 152, 'paths': [{'path': [57, 53, 120, 29, 1, 98, 147, 109, 104, 152], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [57, 37, 32, 114, 91, 83, 147, 25, 49, 74, 5, 120, 116, 40, 30, 152], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [57, 85, 151, 125, 108, 104, 138, 43, 67, 54, 144, 139, 49, 102, 11, 152], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [57, 69, 152], 'end-to-end_transmission': 0, 'latency': 60, 'cost': 0}, {'path': [57, 53, 72, 151, 77, 97, 61, 62, 118, 43, 138, 140, 45, 49, 120, 92, 115, 3, 104, 108, 125, 152], 'end-to-end_transmission': 0, 'latency': 630, 'cost': 0}, {'path': [57, 53, 146, 101, 137, 114, 122, 50, 80, 125, 108, 104, 142, 99, 152], 'end-to-end_transmission': 0, 'latency': 420, 'cost': 0}, {'path': [57, 97, 98, 121, 18, 79, 122, 50, 141, 33, 142, 125, 152], 'end-to-end_transmission': 0, 'latency': 360, 'cost': 0}, {'path': [57, 72, 43, 56, 108, 125, 111, 70, 44, 152], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [57, 53, 14, 73, 49, 103, 36, 115, 59, 135, 134, 133, 146, 150, 96, 54, 68, 56, 3, 23, 142, 125, 152], 'end-to-end_transmission': 1, 'latency': 660, 'cost': 2.227}, {'path': [57, 72, 61, 92, 115, 135, 36, 120, 41, 124, 28, 15, 131, 129, 79, 107, 16, 50, 56, 44, 119, 51, 152], 'end-to-end_transmission': 1, 'latency': 660, 'cost': 1.227}]})
# --------------------------------------------------------
# ant 17: ({'start_node': 90, 'destination_node': 151, 'paths': [{'path': [90, 145, 32, 152, 15, 30, 118, 16, 151], 'end-to-end_transmission': 0, 'latency': 240, 'cost': 0}, {'path': [90, 44, 43, 117, 40, 59, 101, 143, 126, 41, 45, 142, 99, 69, 68, 12, 140, 1, 72, 138, 79, 23, 134, 42, 151], 'end-to-end_transmission': 0, 'latency': 720, 'cost': 0}, {'path': [90, 32, 88, 59, 50, 129, 151], 'end-to-end_transmission': 0, 'latency': 180, 'cost': 0}, {'path': [90, 70, 64, 147, 137, 114, 45, 52, 74, 107, 34, 22, 117, 142, 33, 141, 14, 116, 59, 101, 25, 92, 40, 77, 123, 43, 56, 151], 'end-to-end_transmission': 0, 'latency': 810, 'cost': 0}, {'path': [90, 145, 62, 115, 94, 53, 86, 100, 1, 151], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [90, 62, 118, 41, 92, 115, 35, 130, 106, 7, 53, 151], 'end-to-end_transmission': 0, 'latency': 330, 'cost': 0}, {'path': [90, 72, 151], 'end-to-end_transmission': 3, 'latency': 60, 'cost': 5.5}, {'path': [90, 14, 53, 151], 'end-to-end_transmission': 4, 'latency': 90, 'cost': 5.667}, {'path': [90, 62, 66, 116, 139, 131, 27, 14, 53, 77, 151], 'end-to-end_transmission': 1, 'latency': 300, 'cost': 2.5}, {'path': [90, 57, 15, 145, 84, 62, 105, 14, 53, 151], 'end-to-end_transmission': 3, 'latency': 270, 'cost': 4.556}]})
# --------------------------------------------------------
# ant 18: ({'start_node': 90, 'destination_node': 152, 'paths': [{'path': [90, 73, 53, 11, 93, 141, 45, 104, 23, 113, 108, 125, 4, 102, 150, 47, 24, 72, 12, 152], 'end-to-end_transmission': 0, 'latency': 570, 'cost': 0}, {'path': [90, 64, 107, 70, 67, 118, 31, 129, 28, 124, 6, 54, 39, 123, 82, 35, 130, 45, 103, 145, 110, 66, 152], 'end-to-end_transmission': 0, 'latency': 660, 'cost': 0}, {'
# --------------------------------------------------------
# ant 20: ({'start_node': 108, 'destination_node': 152, 'paths': [{'path': [108, 124, 125, 8, 16, 129, 104, 3, 106, 11, 152], 'end-to-end_transmission': 0, 'latency': 300, 'cost': 0}, {'path': [108, 151, 107, 45, 82, 75, 128, 113, 147, 87, 114, 145, 62, 152], 'end-to-end_transmission': 0, 'latency': 390, 'cost': 0}, {'path': [108, 104, 137, 42, 113, 105, 97, 59, 116, 45, 53, 57, 48, 86, 125, 152], 'end-to-end_transmission': 0, 'latency': 450, 'cost': 0}, {'path': [108, 65, 109, 32, 137, 90, 73, 106, 47, 10, 81, 64, 116, 4, 152], 'end-to-end_transmission': 0, 'latency': 420, 'cost': 0}, {'path': [108, 99, 152], 'end-to-end_transmission': 4, 'latency': 60, 'cost': 7.5}, {'path': [108, 125, 99, 152], 'end-to-end_transmission': 3, 'latency': 90, 'cost': 6.667}, {'path': [108, 69, 65, 130, 39, 102, 37, 74, 118, 62, 90, 84, 145, 14, 53, 78, 141, 33, 7, 79, 122, 125, 152], 'end-to-end_transmission': 0, 'latency': 660, 'cost': 0}, {'path': [108, 64, 113, 16, 7, 79, 122, 39, 123, 152], 'end-to-end_transmission': 0, 'latency': 270, 'cost': 0}, {'path': [108, 69, 51, 34, 65, 46, 112, 58, 87, 54, 106, 130, 91, 80, 70, 44, 152], 'end-to-end_transmission': 1, 'latency': 480, 'cost': 3.312}, {'path': [108, 99, 152], 'end-to-end_transmission': 4, 'latency': 60, 'cost': 7.5}]})
# --------------------------------------------------------
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing dijkstras algorithm...
# -------------------------------------------------------------------------------------------------------------------------------------
# Optimal route to 151: 108 -> 68 -> 24 -> 54 -> 21 -> 17 -> 55 -> 6 -> 52 -> 10 -> 35 -> 85 -> 45 -> 129 -> 41 -> 28 -> 61 -> 72 -> 15 -> 53 -> 57 -> 151
# Data Transmission Rate: 1 Mbps
# Total Latency: 630 ms
# Absolute cost: 1.238
# Optimal route to 152: 108 -> 152
# Data Transmission Rate: 2 Mbps
# Total Latency: 30 ms
# Absolute cost: 7.0
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing simulated annealing...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
def get_algorithm_accuracy_metrics(trials=4):
    """
    get_algorithm_accuracy_metrics()
    ranks the algorithms in terms of the quality of the solutions they provide.
    The ranking is done by running the several runs of all algorithms, ranking 
    the individual ranks then ranking the ranks in order to get a wholistic rank
    of the algorithms. The ranks are then displayed on a table. Rank ties 
    could exist in some scenarios
    returns: nothing
    """
    # choose any random node to start from with the exception of the base stations
    dest_nodes = [x_y_base_station_1[0], x_y_base_station_2[0]]
    # list of algorithms whose time performance will be compared
    methods = ['discrete genetic algorithm', 'ant colony optimization', 'dijkstras algorithm', 'simulated annealing']
    accuracy_performance = []
    # initialize the sum of ranks for overall ranking
    rank_sum = np.zeros(len(methods))
    trial_no = trials
    # create a store for the final rank data
    overall_performance = []
    for trial in range(trial_no):
        start_node = choice(np.array([i for i in x_y_data.keys() if i not in dest_nodes]), 1, replace=False)[0]
        print(f"trial {trial + 1}...")
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        path_costs = []
        for method in methods:      
            print(f"executing {method}; trial {trial + 1}...")
            '''
            run the algorithm and get the solutions data with contains 
            the albolute cost which is used to dictate the quality of 
            the solution. The higher the cost the better the rank
            '''
            if method == "discrete genetic algorithm":
                results, solutions = discrete_genetic_algorithm(start_node)
            elif method == "dijkstras algorithm":
                results, solutions = dijkstra_algorithm(start_node)
            elif method == "ant colony optimization":
                results, solutions = ant_colony_optimization(start_node)
            elif method == "simulated annealing":
                results, solutions = simulated_annealing(start_node)
            path_costs.append(float(solutions[0]['absolute path cost']))
        # rank the path costs. negate the costs so that ranking is done in descending order
        ranked_costs = stat.rankdata([-cost for cost in path_costs])
        accuracy_performance.append(list(map(int, ranked_costs)))
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    #compile the individual trial ranks into a single wholistic rank
    for ranks in range(len(accuracy_performance)):
        for method in range(len(methods)):
            rank_sum[method] += accuracy_performance[ranks][method]
    # rank the sum of the individual ranks
    rank_data = list(map(int,stat.rankdata(rank_sum)))
    for i in range(len(rank_data)):
        overall_performance.append([rank_data[i], methods[i]])
    # tabulate the overall rank
    show_algorithm_accuracy_rank(overall_performance)

    return

# %%
get_algorithm_accuracy_metrics()
# Out:
# trial 1...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing discrete genetic algorithm; trial 1...
# **********************************Generation 1**********************************
# ********************************************Performance**********************************
# *****************************************************************************************
# No Solution Found to base station ID 151
# **********************************Generation 1**********************************
# ********************************************Performance**********************************
# Chromosome: [123  51 152]-----actual route: 123->51->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123  69 152]-----actual route: 123->69->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123  56 152]-----actual route: 123->56->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123 125 152]-----actual route: 123->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 111 152]-----actual route: 123->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123  99 152]-----actual route: 123->99->152->----Score (end-to-end path cost): 7.5
# Chromosome: [123 104 152]-----actual route: 123->104->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 108 152]-----actual route: 123->108->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123  60 152]-----actual route: 123->60->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123 126 152]-----actual route: 123->126->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123  44 152]-----actual route: 123->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [123  23 152]-----actual route: 123->23->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123  39 104 152]-----actual route: 123->39->104->152->----Score (end-to-end path cost): 2.667
# Chromosome: [123  70 152]-----actual route: 123->70->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123   3 152]-----actual route: 123->3->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123   3 108 152]-----actual route: 123->3108->152->----Score (end-to-end path cost): 3.667
# Chromosome: [123 142 152]-----actual route: 123->142->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123   3  44 152]-----actual route: 123->344->152->----Score (end-to-end path cost): 4.667
# Chromosome: [123  60 119 107  56 152]-----actual route: 123->60->119->107->56->152->----Score (end-to-end path cost): 2.0
# Chromosome: [123  56  99 152]-----actual route: 123->56->99->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 2**********************************
# ********************************************Performance**********************************
# Chromosome: [123 51 152]-----actual route: 123->51->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123 56 152]-----actual route: 123->56->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123 125 152]-----actual route: 123->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 111 152]-----actual route: 123->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 99 152]-----actual route: 123->99->152->----Score (end-to-end path cost): 7.5
# Chromosome: [123 104 152]-----actual route: 123->104->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 108 152]-----actual route: 123->108->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 60 152]-----actual route: 123->60->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123 44 152]-----actual route: 123->44->152->----Score (end-to-end path cost): 5.5
# Chromosome: [123 70 152]-----actual route: 123->70->152->----Score (end-to-end path cost): 3.5
# Chromosome: [123 3 108 152]-----actual route: 123->3108->152->----Score (end-to-end path cost): 3.667
# Chromosome: [123 3 44 152]-----actual route: 123->344->152->----Score (end-to-end path cost): 4.667
# Chromosome: [123  56  99 152]-----actual route: 123->56->99->152->----Score (end-to-end path cost): 3.667
# *****************************************************************************************
# **********************************Generation 3**********************************
# ********************************************Performance**********************************
# Chromosome: [123 125 152]-----actual route: 123->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 111 152]-----actual route: 123->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 99 152]-----actual route: 123->99->152->----Score (end-to-end path cost): 7.5
# Chromosome: [123 104 152]-----actual route: 123->104->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123, 108, 152]-----actual route: 123->108->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123, 3, 108, 152]-----actual route: 123->3108->152->----Score (end-to-end path cost): 3.667
# Chromosome: [123 3 44 152]-----actual route: 123->344->152->----Score (end-to-end path cost): 4.667
# *****************************************************************************************
# **********************************Generation 4**********************************
# ********************************************Performance**********************************
# Chromosome: [123 125 152]-----actual route: 123->125->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 111 152]-----actual route: 123->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 99 152]-----actual route: 123->99->152->----Score (end-to-end path cost): 7.5
# Chromosome: [123 104 152]-----actual route: 123->104->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123, 108, 152]-----actual route: 123->108->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123, 3, 44, 152]-----actual route: 123->344->152->----Score (end-to-end path cost): 4.667
# *****************************************************************************************
# **********************************Generation 5**********************************
# ********************************************Performance**********************************
# Chromosome: [123 111 152]-----actual route: 123->111->152->----Score (end-to-end path cost): 4.5
# Chromosome: [123 99 152]-----actual route: 123->99->152->----Score (end-to-end path cost): 7.5
# *****************************************************************************************
# **********************************Generation 6**********************************
# ********************************************Performance**********************************
# Chromosome: [123 99 152]-----actual route: 123->99->152->----Score (end-to-end path cost): 7.5
# *****************************************************************************************
# executing ant colony optimization; trial 1...

# %%
for algorithm, sensors in get_missing_solutions().items():
    for sensor in sensors:
        try:
            print(f"Sensor {sensor}")
            find_optimal_route(sensor, algorithm)
        except:
            pass
# Out:
# **********************************Generation 1**********************************
# ********************************************Performance**********************************
# *****************************************************************************************
# No Solution Found to base station ID 151
# **********************************Generation 1**********************************
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ********************************************Performance**********************************
# *****************************************************************************************
# No Solution Found to base station ID 152
# Traceback (most recent call last):
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3366881060.py", line 25, in discrete_genetic_algorithm
#     dga_data, solutions = dga_run(origin, destination, pop_length=pop_length, generations=generations, mutation_rate=mutation_rate, type=crossover_type, selection_limit=selection_limit)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/2326669210.py", line 34, in dga_run
#     selection_winners = tournament_fitness_selection(pop_fitness_data, selection_limit=selection_limit)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/723720401.py", line 32, in tournament_fitness_selection
#     selected_winners.append(pop_fitness_data[0][0])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3366881060.py", line 29, in discrete_genetic_algorithm
#     dga_data, solutions = dga_run(origin, destination, pop_length=pop_length, generations=generations, mutation_rate=mutation_rate, type=crossover_type, selection_limit=selection_limit)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/2326669210.py", line 34, in dga_run
#     selection_winners = tournament_fitness_selection(pop_fitness_data, selection_limit=selection_limit)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/723720401.py", line 32, in tournament_fitness_selection
#     selected_winners.append(pop_fitness_data[0][0])
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/samuelmariwa/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/1925455594.py", line 3, in <module>
#     find_optimal_route(sensor, algorithm)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3012020432.py", line 25, in find_optimal_route
#     results, solutions = discrete_genetic_algorithm(origin, **kwargs)
#   File "/var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3366881060.py", line 31, in discrete_genetic_algorithm
#     sys.exit("No Solution Found")
# SystemExit: No Solution Found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/samuelmariwa/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/samuelmariwa/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/samuelmariwa/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/samuelmariwa/opt/anaconda3/lib/python3.9/inspect.py", line 1543, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3366881060.py in discrete_genetic_algorithm(origin, pop_length, generations, mutation_rate, crossover_type, selection_limit)
#      24             destination = x_y_base_station_1[0]
# ---> 25             dga_data, solutions = dga_run(origin, destination, pop_length=pop_length, generations=generations, mutation_rate=mutation_rate, type=crossover_type, selection_limit=selection_limit)
#      26         except Exception as e:
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/2326669210.py in dga_run(origin, destination, pop_length, generations, mutation_rate, type, selection_limit)
#      33         # perform selection
# ---> 34         selection_winners = tournament_fitness_selection(pop_fitness_data, selection_limit=selection_limit)
#      35         # perform pairing for crossover
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/723720401.py in tournament_fitness_selection(pop_fitness_data, selection_limit)
#      31     else:
# ---> 32         selected_winners.append(pop_fitness_data[0][0])
#      33
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3366881060.py in discrete_genetic_algorithm(origin, pop_length, generations, mutation_rate, crossover_type, selection_limit)
#      28             destination = x_y_base_station_2[0]
# ---> 29             dga_data, solutions = dga_run(origin, destination, pop_length=pop_length, generations=generations, mutation_rate=mutation_rate, type=crossover_type, selection_limit=selection_limit)
#      30     except:
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/2326669210.py in dga_run(origin, destination, pop_length, generations, mutation_rate, type, selection_limit)
#      33         # perform selection
# ---> 34         selection_winners = tournament_fitness_selection(pop_fitness_data, selection_limit=selection_limit)
#      35         # perform pairing for crossover
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/723720401.py in tournament_fitness_selection(pop_fitness_data, selection_limit)
#      31     else:
# ---> 32         selected_winners.append(pop_fitness_data[0][0])
#      33
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/1925455594.py in <module>
#       2     for sensor in sensors:
# ----> 3         find_optimal_route(sensor, algorithm)
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3012020432.py in find_optimal_route(origin, method, **kwargs)
#      24     if method == "discrete genetic algorithm":
# ---> 25         results, solutions = discrete_genetic_algorithm(origin, **kwargs)
#      26     elif method == "dijkstras algorithm":
#
# /var/folders/3m/7yx097tn2wz5t7h3fbj4dj_00000gn/T/ipykernel_42257/3366881060.py in discrete_genetic_algorithm(origin, pop_length, generations, mutation_rate, crossover_type, selection_limit)
#      30     except:
# ---> 31         sys.exit("No Solution Found")
#      32
#
# SystemExit: No Solution Found
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2068                     stb = ['An exception has occurred, use %tb to see '
#    2069                            'the full traceback.\n']
# -> 2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2071                                                                      value))
#    2072                 else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
