# %%
import ast
import json
# %run data_plot.ipynb
# %run metrics.ipynb
# %run discrete_genetic_algorithm.ipynb
# %run ant_colony_optimization.ipynb
# %run dijkstras_algorithm.ipynb
# %run differential_evolution.ipynb
# %run particle_swarm_optimization.ipynb

# %%
def parse_map_data(results):
    coordinates = {'best_route': {'sensor_id': [],
                              'coordinates': []}, 
               'possible_routes': []
              }
    possible_paths = [ast.literal_eval(paths) for paths in results['possible_paths'].keys()]
    for path in possible_paths:
        route_coords = []
        possible_path_dest_idx = len(path) - 1
        for idx, sensor in enumerate(path):
            if idx != 0 and idx != possible_path_dest_idx:
                route_coords.append(geographic_coords[str(sensor)])
                route_coords.append(geographic_coords[str(sensor)])
            else:
                route_coords.append(geographic_coords[str(sensor)])
        coordinates['possible_routes'].append(route_coords)
    # add best path last so that an visual it appears on top
    best_path = ast.literal_eval(list(results['best_path'].keys())[0])
    best_path_dest_idx = len(best_path) - 1
    for idx, sensor in enumerate(best_path):
        if idx != best_path_dest_idx:
            coordinates['best_route']['sensor_id'].append(sensor)
        if idx != 0 and idx != best_path_dest_idx:
            coordinates['best_route']['coordinates'].append(geographic_coords[str(sensor)])
            coordinates['best_route']['coordinates'].append(geographic_coords[str(sensor)])
        else:
            coordinates['best_route']['coordinates'].append(geographic_coords[str(sensor)])

    return coordinates

# %%
def save_solution(solution, method):
    existing_solutions = load_solutions()
    if method in existing_solutions.keys():
        existing_solutions[method][solution[0]['source node']] = solution[0]
    else:
        existing_solutions[method] = {}
        existing_solutions[method][solution[0]['source node']] = solution[0]
        
    json.dump(existing_solutions, open( f"solutions.json", 'w' ) )

    return

# %%
def load_solutions():
    with open('solutions.json', 'r') as file:
        try:
            solutions = json.load(file)
        except Exception as e:
            solutions = {}
    return solutions

# %%
def find_optimal_route(origin, method, **kwargs):

    if method == "discrete genetic algorithm":
        results, solutions = results, solutions = discrete_genetic_algorithm(origin, **kwargs)
    elif method == "dijkstras algorithm":
        results, solutions = dijkstra_algorithm(origin)
    elif method == "ant colony optimization":
        results, solutions = ant_colony_optimization(origin, **kwargs)
    else:
        return "unknown algorithm"
    save_solution(solutions, method)
    coordinates = parse_map_data(results)
    plot_route(coordinates)

    return

# %%
#find_optimal_route(43, 'discrete genetic algorithm', pop_length=100000)
#find_optimal_route(1, 'ant colony optimization')
#find_optimal_route(101, 'dijkstras algorithm')

# %%
def run_all():
    methods = ['dijkstras algorithm'] #['discrete genetic algorithm', 'ant colony optimization', 'dijkstras algorithm']
    sensors = list(x_y_data.keys())[:-2]
    for method in methods:
        for sensor in sensors:
            try:
                print(f"Sensor {sensor}")
                find_optimal_route(sensor, method)
            except:
                pass        

    return

# %%
#run_all()

# %%
def get_algorithm_time_metrics():
    dest_nodes = [x_y_base_station_1[0], x_y_base_station_2[0]]
    start_node = choice(np.array([i for i in x_y_data.keys() if i not in dest_nodes]), 1, replace=False)[0]
    methods = ['discrete genetic algorithm', 'ant colony optimization', 'dijkstras algorithm']
    for method in methods:
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        print(f"executing {method}...")
        start_execution()
        find_optimal_route(start_node, method)
        stop_execution(method)
        print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
    plot_algorithm_execution_time()

# %%
get_algorithm_time_metrics()
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing discrete genetic algorithm...
# **********************************Generation 1**********************************
# ********************************************Performance**********************************
# Chromosome: [ 78  90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [ 78  77  61 151]-----actual route: 78->77->61->151->----Score (end-to-end path cost): 2.667
# Chromosome: [ 78  27  61 151]-----actual route: 78->27->61->151->----Score (end-to-end path cost): 2.667
# Chromosome: [ 78  77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [ 78  61 151]-----actual route: 78->61->151->----Score (end-to-end path cost): 3.5
# Chromosome: [ 78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [ 78  14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# Chromosome: [ 78 131  90 151]-----actual route: 78->131->90->151->----Score (end-to-end path cost): 2.667
# *****************************************************************************************
# **********************************Generation 2**********************************
# ********************************************Performance**********************************
# Chromosome: [78, 90, 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78, 27, 61, 151]-----actual route: 78->27->61->151->----Score (end-to-end path cost): 2.667
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [ 78  14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 3**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 4**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 5**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 6**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 7**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 8**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 9**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# **********************************Generation 10**********************************
# ********************************************Performance**********************************
# Chromosome: [78 90 151]-----actual route: 78->90->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 77 151]-----actual route: 78->77->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 145 151]-----actual route: 78->145->151->----Score (end-to-end path cost): 4.5
# Chromosome: [78 14 151]-----actual route: 78->14->151->----Score (end-to-end path cost): 4.5
# *****************************************************************************************
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26c10afa8ca963a0dea06d041aa3571e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26c10afa8ca963a0dea06d041aa3571e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26c10afa8ca963a0dea06d041aa3571e = L.map(
#                 &quot;map_26c10afa8ca963a0dea06d041aa3571e&quot;,
#                 {
#                     center: [50.83978562392831, -1.5107262950382598],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#
#
#
#             var tile_layer_24d42eab97dcf96bcbd81feca2dd88f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 12, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#             var marker_8d84301c0970ff6c7e18226393a3b4ba = L.marker(
#                 [50.817205047239135, -1.4493866785949845],
#                 {}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_4638eb92ad70f2eb1d1128c345761607 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9753a9699a824c060b714deb798dbc8d = $(`&lt;div id=&quot;html_9753a9699a824c060b714deb798dbc8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base Station 1&lt;/div&gt;`)[0];
#                 popup_4638eb92ad70f2eb1d1128c345761607.setContent(html_9753a9699a824c060b714deb798dbc8d);
#
#
#
#         marker_8d84301c0970ff6c7e18226393a3b4ba.bindPopup(popup_4638eb92ad70f2eb1d1128c345761607)
#         ;
#
#
#
#
#             var marker_b34212ab18ee041dc1a3c8c5db2514a9 = L.marker(
#                 [50.86236620061749, -1.5720659114815352],
#                 {}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_5ca65ea7499cfe162286b0bfe2469eec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5346f4655ecb7459f471de32c95341cc = $(`&lt;div id=&quot;html_5346f4655ecb7459f471de32c95341cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base Station 2&lt;/div&gt;`)[0];
#                 popup_5ca65ea7499cfe162286b0bfe2469eec.setContent(html_5346f4655ecb7459f471de32c95341cc);
#
#
#
#         marker_b34212ab18ee041dc1a3c8c5db2514a9.bindPopup(popup_5ca65ea7499cfe162286b0bfe2469eec)
#         ;
#
#
#
#
#             var circle_marker_f17a49abb2390ee4f8109ca3c7e3ee60 = L.circleMarker(
#                 [50.883979557402725, -1.4739697955535238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_1acaa615010b52362d98bf32525a1501 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16e2f682183905b2257c2faaaf2fd5e1 = $(`&lt;div id=&quot;html_16e2f682183905b2257c2faaaf2fd5e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor ID: 1&lt;/div&gt;`)[0];
#                 popup_1acaa615010b52362d98bf32525a1501.setContent(html_16e2f682183905b2257c2faaaf2fd5e1);
#
#
#
#         circle_marker_f17a49abb2390ee4f8109ca3c7e3ee60.bindPopup(popup_1acaa615010b52362d98bf32525a1501)
#         ;
#
#
#
#
#             var circle_marker_27de41cfd1858c08c13fe3dc2fa58bc6 = L.circleMarker(
#                 [50.8006218060326, -1.5355823347936448],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_1cca162529d72167b063d57219c8598d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# executing dijkstras algorithm...
# -------------------------------------------------------------------------------------------------------------------------------------
# Optimal route to 151: 78 -> 77 -> 90 -> 53 -> 57 -> 151
# Data Transmission Rate: 2 Mbps
# Total Latency: 150 ms
# Absolute cost: 3.0
# Optimal route to 152: 78 -> 124 -> 138 -> 116 -> 19 -> 46 -> 7 -> 16 -> 22 -> 33 -> 39 -> 50 -> 51 -> 111 -> 44 -> 99 -> 152
# Data Transmission Rate: 1 Mbps
# Total Latency: 480 ms
# Absolute cost: 1.312
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26c10afa8ca963a0dea06d041aa3571e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26c10afa8ca963a0dea06d041aa3571e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26c10afa8ca963a0dea06d041aa3571e = L.map(
#                 &quot;map_26c10afa8ca963a0dea06d041aa3571e&quot;,
#                 {
#                     center: [50.83978562392831, -1.5107262950382598],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#
#
#
#             var tile_layer_24d42eab97dcf96bcbd81feca2dd88f9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 12, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#             var marker_8d84301c0970ff6c7e18226393a3b4ba = L.marker(
#                 [50.817205047239135, -1.4493866785949845],
#                 {}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_4638eb92ad70f2eb1d1128c345761607 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9753a9699a824c060b714deb798dbc8d = $(`&lt;div id=&quot;html_9753a9699a824c060b714deb798dbc8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base Station 1&lt;/div&gt;`)[0];
#                 popup_4638eb92ad70f2eb1d1128c345761607.setContent(html_9753a9699a824c060b714deb798dbc8d);
#
#
#
#         marker_8d84301c0970ff6c7e18226393a3b4ba.bindPopup(popup_4638eb92ad70f2eb1d1128c345761607)
#         ;
#
#
#
#
#             var marker_b34212ab18ee041dc1a3c8c5db2514a9 = L.marker(
#                 [50.86236620061749, -1.5720659114815352],
#                 {}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_5ca65ea7499cfe162286b0bfe2469eec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5346f4655ecb7459f471de32c95341cc = $(`&lt;div id=&quot;html_5346f4655ecb7459f471de32c95341cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Base Station 2&lt;/div&gt;`)[0];
#                 popup_5ca65ea7499cfe162286b0bfe2469eec.setContent(html_5346f4655ecb7459f471de32c95341cc);
#
#
#
#         marker_b34212ab18ee041dc1a3c8c5db2514a9.bindPopup(popup_5ca65ea7499cfe162286b0bfe2469eec)
#         ;
#
#
#
#
#             var circle_marker_f17a49abb2390ee4f8109ca3c7e3ee60 = L.circleMarker(
#                 [50.883979557402725, -1.4739697955535238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_1acaa615010b52362d98bf32525a1501 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16e2f682183905b2257c2faaaf2fd5e1 = $(`&lt;div id=&quot;html_16e2f682183905b2257c2faaaf2fd5e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sensor ID: 1&lt;/div&gt;`)[0];
#                 popup_1acaa615010b52362d98bf32525a1501.setContent(html_16e2f682183905b2257c2faaaf2fd5e1);
#
#
#
#         circle_marker_f17a49abb2390ee4f8109ca3c7e3ee60.bindPopup(popup_1acaa615010b52362d98bf32525a1501)
#         ;
#
#
#
#
#             var circle_marker_27de41cfd1858c08c13fe3dc2fa58bc6 = L.circleMarker(
#                 [50.8006218060326, -1.5355823347936448],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_26c10afa8ca963a0dea06d041aa3571e);
#
#
#         var popup_1cca162529d72167b063d57219c8598d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
